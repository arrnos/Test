# %%
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)
pd.set_option('display.unicode.ambiguous_as_wide', True)
pd.set_option('display.unicode.east_asian_width', True)
np.set_printoptions(threshold=np.inf)
plt.rcParams['font.sans-serif'] = ['SimHei']  # 中文字体设置-黑体
plt.rcParams['axes.unicode_minus'] = False  # 解决保存图像是负号'-'显示为方块的问题
sns.set(font='SimHei')  # 解决Seaborn中文显示问题


# %matplotlib inline
sns.set(style="whitegrid")

cate_features =['alignment_day', 'alignment_day_of_week', 'alignment_hour', 'alignment_month', 'alignment_year', 'consult_type', 'contain_education_or_promotion_key_word_in_dialogue', 'contain_price_key_word_in_dialogue', 'create_user', 'dialogue_start_at', 'educationalBackground', 'first_proj_id', 'gender', 'graduateSchool', 'major', 'marriageState', 'nationalEdu', 'oppor_source', 'posLevel', 'promotion_type', 'quantum_id', 'race', 'residenceType', 'site_source', 'student_cellphone_midnum', 'twice_consult']
cont_features = ['account_age', 'all_call_num', 'avgerage_waiting_time_of_dialogue', 'delta_days_from_entryDate', 'delta_time_of_create_time_and_operator_time', 'duration_of_dialogue', 'message_opp_distribution_num', 'message_opp_distribution_saturation', 'message_opp_limit_num', 'number_of_dialogue', 'number_of_student_dialogue', 'online_opp_distribution_num', 'online_opp_distribution_saturation', 'online_opp_limit_num', 'opp_completed_rate', 'opp_following_num', 'opp_today_following_num', 'pastNday_advertiser_applied_ratio', 'pastNday_advertiser_distribution_num', 'pastNday_advertiser_order_num', 'pastNday_applied_ratio_on_siteId', 'pastNday_distribution_num_on_siteId', 'pastNday_order_num_on_siteId', 'past_n_days_acc_alignment_num', 'past_n_days_acc_order_amount', 'past_n_days_acc_order_avg_amount', 'past_n_days_acc_order_num', 'past_n_days_acc_order_rate', 'recycle_opp_distribution_num', 'recycle_opp_distribution_saturation', 'recycle_opp_limit_num', 'timedelta_from', 'today_unfollowed_num', 'valid_call_num']
csv_features = ['label', 'account_age', 'alignment_day', 'alignment_day_of_week', 'alignment_hour', 'alignment_month', 'alignment_year', 'all_call_num', 'avgerage_waiting_time_of_dialogue', 'consult_type', 'contain_education_or_promotion_key_word_in_dialogue', 'contain_price_key_word_in_dialogue', 'create_user', 'delta_days_from_entryDate', 'delta_time_of_create_time_and_operator_time', 'dialogue_start_at', 'duration_of_dialogue', 'educationalBackground', 'first_proj_id', 'gender', 'graduateSchool', 'major', 'marriageState', 'message_opp_distribution_num', 'message_opp_distribution_saturation', 'message_opp_limit_num', 'nationalEdu', 'number_of_dialogue', 'number_of_student_dialogue', 'online_opp_distribution_num', 'online_opp_distribution_saturation', 'online_opp_limit_num', 'opp_completed_rate', 'opp_following_num', 'opp_today_following_num', 'oppor_source', 'pastNday_advertiser_applied_ratio', 'pastNday_advertiser_distribution_num', 'pastNday_advertiser_order_num', 'pastNday_applied_ratio_on_siteId', 'pastNday_distribution_num_on_siteId', 'pastNday_order_num_on_siteId', 'past_n_days_acc_alignment_num', 'past_n_days_acc_order_amount', 'past_n_days_acc_order_avg_amount', 'past_n_days_acc_order_num', 'past_n_days_acc_order_rate', 'posLevel', 'promotion_type', 'quantum_id', 'race', 'recycle_opp_distribution_num', 'recycle_opp_distribution_saturation', 'recycle_opp_limit_num', 'residenceType', 'site_source', 'student_cellphone_midnum', 'student_dialogue_fenci', 'timedelta_from', 'today_unfollowed_num', 'twice_consult', 'valid_call_num']

csv_file = "E:\project_data\Test\\train_csv_feature_sample"

df = pd.read_csv(csv_file)
df.columns = csv_features

feature_ls  = list([(x,'category') for x in ["label"]+cate_features]+[(x,float) for x in cont_features])
dtypes = dict(feature_ls)
df = df.astype(dtypes)
n = len(df)
# df.dtypes

# %%
for feature in cont_features:
    feature_value = df[feature]
    print("[%s]"%feature)
    print("缺失率：%.0f%%"%(feature_value.isna().sum()/n*100))
    percentiles = list(np.arange(8)*0.1)+list(np.arange(8,10,0.5)*0.1)
    print(feature_value.describe(percentiles=percentiles))
    sns.violinplot(x=feature_value)
    plt.show()
# Out:
# [account_age]
# 缺失率：2%
# count    97238.000000
# mean        24.261636
# std          2.970119
# min         17.000000
# 0%          17.000000
# 10%         21.000000
# 20%         22.000000
# 30.0%       23.000000
# 40%         23.000000
# 50%         24.000000
# 60.0%       25.000000
# 70%         25.000000
# 80%         26.000000
# 85.0%       27.000000
# 90%         28.000000
# 95%         30.000000
# max         46.000000
# Name: account_age, dtype: float64
# [all_call_num]
# 缺失率：61%
# count    38705.000000
# mean        35.856168
# std         45.636119
# min          1.000000
# 0%           1.000000
# 10%          2.000000
# 20%          4.000000
# 30.0%        7.000000
# 40%         12.000000
# 50%         18.000000
# 60.0%       27.000000
# 70%         40.000000
# 80%         59.000000
# 85.0%       75.000000
# 90%         96.000000
# 95%        130.000000
# max        530.000000
# Name: all_call_num, dtype: float64
# [avgerage_waiting_time_of_dialogue]
# 缺失率：36%
# count    63542.000000
# mean        10.413254
# std         42.514261
# min          1.000000
# 0%           1.000000
# 10%          4.000000
# 20%          5.000000
# 30.0%        6.000000
# 40%          6.000000
# 50%          7.000000
# 60.0%        8.000000
# 70%          8.000000
# 80%         10.000000
# 85.0%       11.000000
# 90%         13.000000
# 95%         17.000000
# max       4710.000000
# Name: avgerage_waiting_time_of_dialogue, dtype: float64
# [delta_days_from_entryDate]
# 缺失率：9%
# count    90978.000000
# mean       267.526963
# std        277.496956
# min          1.000000
# 0%           1.000000
# 10%         21.000000
# 20%         43.000000
# 30.0%       77.000000
# 40%        120.000000
# 50%        184.000000
# 60.0%      253.000000
# 70%        354.000000
# 80%        460.000000
# 85.0%      532.000000
# 90%        632.000000
# 95%        779.000000
# max       4001.000000
# Name: delta_days_from_entryDate, dtype: float64
# [delta_time_of_create_time_and_operator_time]
# 缺失率：0%
# count    9.949000e+04
# mean     7.531551e+05
# std      1.636525e+06
# min      5.000000e+00
# 0%       5.000000e+00
# 10%      2.500000e+01
# 20%      3.700000e+01
# 30.0%    4.900000e+01
# 40%      8.700000e+01
# 50%      1.137000e+03
# 60.0%    5.315000e+03
# 70%      4.841660e+04
# 80%      1.120960e+06
# 85.0%    1.828620e+06
# 90%      3.031819e+06
# 95%      5.005079e+06
# max      7.915337e+06
# Name: delta_time_of_create_time_and_operator_time, dtype: float64
# [duration_of_dialogue]
# 缺失率：36%
# count    63543.000000
# mean       146.124058
# std        521.377778
# min          0.000000
# 0%           0.000000
# 10%         54.000000
# 20%         64.000000
# 30.0%       72.000000
# 40%         81.000000
# 50%         91.000000
# 60.0%      102.000000
# 70%        119.000000
# 80%        144.000000
# 85.0%      164.000000
# 90%        197.000000
# 95%        275.000000
# max      37018.000000
# Name: duration_of_dialogue, dtype: float64
# [message_opp_distribution_num]
# 缺失率：11%
# count    88857.000000
# mean         2.671011
# std          4.158010
# min          0.000000
# 0%           0.000000
# 10%          0.000000
# 20%          0.000000
# 30.0%        0.000000
# 40%          1.000000
# 50%          1.000000
# 60.0%        2.000000
# 70%          3.000000
# 80%          4.000000
# 85.0%        5.000000
# 90%          7.000000
# 95%         11.000000
# max         78.000000
# Name: message_opp_distribution_num, dtype: float64
# [message_opp_distribution_saturation]
# 缺失率：11%
# count    88696.000000
# mean         0.174901
# std          0.229200
# min          0.000000
# 0%           0.000000
# 10%          0.000000
# 20%          0.000000
# 30.0%        0.000000
# 40%          0.050000
# 50%          0.100000
# 60.0%        0.136400
# 70%          0.200000
# 80%          0.320000
# 85.0%        0.400000
# 90%          0.500000
# 95%          0.666700
# max          7.000000
# Name: message_opp_distribution_saturation, dtype: float64
# [message_opp_limit_num]
# 缺失率：11%
# count    88696.000000
# mean        17.304704
# std         12.905808
# min          1.000000
# 0%           1.000000
# 10%          5.000000
# 20%          6.000000
# 30.0%       10.000000
# 40%         10.000000
# 50%         15.000000
# 60.0%       17.000000
# 70%         20.000000
# 80%         27.000000
# 85.0%       30.000000
# 90%         35.000000
# 95%         40.000000
# max        100.000000
# Name: message_opp_limit_num, dtype: float64
# [number_of_dialogue]
# 缺失率：36%
# count    63543.000000
# mean        14.803519
# std          3.041036
# min          1.000000
# 0%           1.000000
# 10%         12.000000
# 20%         13.000000
# 30.0%       13.000000
# 40%         14.000000
# 50%         14.000000
# 60.0%       15.000000
# 70%         16.000000
# 80%         17.000000
# 85.0%       17.000000
# 90%         18.000000
# 95%         20.000000
# max         79.000000
# Name: number_of_dialogue, dtype: float64
# [number_of_student_dialogue]
# 缺失率：36%
# count    63543.000000
# mean         4.435595
# std          1.226358
# min          1.000000
# 0%           1.000000
# 10%          3.000000
# 20%          4.000000
# 30.0%        4.000000
# 40%          4.000000
# 50%          4.000000
# 60.0%        4.000000
# 70%          5.000000
# 80%          5.000000
# 85.0%        5.000000
# 90%          6.000000
# 95%          7.000000
# max         43.000000
# Name: number_of_student_dialogue, dtype: float64
# [online_opp_distribution_num]
# 缺失率：7%
# count    92092.000000
# mean         4.849064
# std          5.787637
# min          0.000000
# 0%           0.000000
# 10%          0.000000
# 20%          0.000000
# 30.0%        1.000000
# 40%          2.000000
# 50%          3.000000
# 60.0%        4.000000
# 70%          6.000000
# 80%          8.000000
# 85.0%       10.000000
# 90%         13.000000
# 95%         17.000000
# max         60.000000
# Name: online_opp_distribution_num, dtype: float64
# [online_opp_distribution_saturation]
# 缺失率：8%
# count    91869.000000
# mean         0.246163
# std          0.255978
# min          0.000000
# 0%           0.000000
# 10%          0.000000
# 20%          0.000000
# 30.0%        0.066700
# 40%          0.111100
# 50%          0.166700
# 60.0%        0.250000
# 70%          0.333300
# 80%          0.444400
# 85.0%        0.510480
# 90%          0.625000
# 95%          0.766700
# max          7.000000
# Name: online_opp_distribution_saturation, dtype: float64
# [online_opp_limit_num]
# 缺失率：8%
# count    91869.000000
# mean        20.919320
# std         12.633703
# min          1.000000
# 0%           1.000000
# 10%          6.000000
# 20%         10.000000
# 30.0%       13.000000
# 40%         15.000000
# 50%         20.000000
# 60.0%       22.000000
# 70%         25.000000
# 80%         30.000000
# 85.0%       35.000000
# 90%         40.000000
# 95%         45.000000
# max        100.000000
# Name: online_opp_limit_num, dtype: float64
# [opp_completed_rate]
# 缺失率：58%
# count    42161.000000
# mean         0.321117
# std          0.206176
# min          0.010100
# 0%           0.010100
# 10%          0.087000
# 20%          0.136400
# 30.0%        0.184200
# 40%          0.235300
# 50%          0.285700
# 60.0%        0.333300
# 70%          0.400000
# 80%          0.500000
# 85.0%        0.500000
# 90%          0.600000
# 95%          0.700000
# max          1.000000
# Name: opp_completed_rate, dtype: float64
# [opp_following_num]
# 缺失率：32%
# count    67568.000000
# mean         7.630950
# std          9.621811
# min          1.000000
# 0%           1.000000
# 10%          1.000000
# 20%          2.000000
# 30.0%        3.000000
# 40%          4.000000
# 50%          5.000000
# 60.0%        6.000000
# 70%          8.000000
# 80%         11.000000
# 85.0%       14.000000
# 90%         17.000000
# 95%         24.000000
# max        562.000000
# Name: opp_following_num, dtype: float64
# [opp_today_following_num]
# 缺失率：58%
# count    42161.000000
# mean         4.115842
# std          3.625397
# min          1.000000
# 0%           1.000000
# 10%          1.000000
# 20%          1.000000
# 30.0%        2.000000
# 40%          2.000000
# 50%          3.000000
# 60.0%        4.000000
# 70%          5.000000
# 80%          6.000000
# 85.0%        7.000000
# 90%          9.000000
# 95%         11.000000
# max         47.000000
# Name: opp_today_following_num, dtype: float64
# [pastNday_advertiser_applied_ratio]
# 缺失率：0%
# count    99469.000000
# mean         0.005811
# std          0.004259
# min          0.000000
# 0%           0.000000
# 10%          0.002300
# 20%          0.003200
# 30.0%        0.003800
# 40%          0.004300
# 50%          0.004700
# 60.0%        0.005200
# 70%          0.006200
# 80%          0.009100
# 85.0%        0.010100
# 90%          0.010700
# 95%          0.011400
# max          0.104200
# Name: pastNday_advertiser_applied_ratio, dtype: float64
# [pastNday_advertiser_distribution_num]
# 缺失率：0%
# count     99469.000000
# mean     287711.934995
# std      163309.088659
# min          11.000000
# 0%           11.000000
# 10%       44387.000000
# 20%      136880.600000
# 30.0%    186033.000000
# 40%      233626.000000
# 50%      306545.000000
# 60.0%    349812.000000
# 70%      387925.000000
# 80%      461576.000000
# 85.0%    485445.000000
# 90%      506163.000000
# 95%      527659.000000
# max      619188.000000
# Name: pastNday_advertiser_distribution_num, dtype: float64
# [pastNday_advertiser_order_num]
# 缺失率：0%
# count    99469.000000
# mean      1380.676040
# std        875.280743
# min          0.000000
# 0%           0.000000
# 10%        369.000000
# 20%        606.000000
# 30.0%      836.000000
# 40%        988.000000
# 50%       1244.000000
# 60.0%     1613.000000
# 70%       1809.000000
# 80%       1995.000000
# 85.0%     2145.000000
# 90%       2425.000000
# 95%       2715.000000
# max       5032.000000
# Name: pastNday_advertiser_order_num, dtype: float64
# [pastNday_applied_ratio_on_siteId]
# 缺失率：4%
# count    95354.000000
# mean         0.125623
# std          0.238059
# min          0.000000
# 0%           0.000000
# 10%          0.000000
# 20%          0.000000
# 30.0%        0.000000
# 40%          0.000000
# 50%          0.052700
# 60.0%        0.091960
# 70%          0.139350
# 80%          0.204120
# 85.0%        0.251750
# 90%          0.321210
# 95%          0.458108
# max          3.584380
# Name: pastNday_applied_ratio_on_siteId, dtype: float64
# [pastNday_distribution_num_on_siteId]
# 缺失率：4%
# count    95354.000000
# mean       682.476823
# std       1161.942636
# min          1.000000
# 0%           1.000000
# 10%         20.000000
# 20%         52.000000
# 30.0%      100.000000
# 40%        166.000000
# 50%        263.000000
# 60.0%      397.000000
# 70%        605.000000
# 80%        960.000000
# 85.0%     1242.000000
# 90%       1755.000000
# 95%       2957.350000
# max      10546.000000
# Name: pastNday_distribution_num_on_siteId, dtype: float64
# [pastNday_order_num_on_siteId]
# 缺失率：4%
# count    95354.000000
# mean         4.600594
# std         14.594142
# min          0.000000
# 0%           0.000000
# 10%          0.000000
# 20%          0.000000
# 30.0%        0.000000
# 40%          0.000000
# 50%          1.000000
# 60.0%        2.000000
# 70%          3.000000
# 80%          5.000000
# 85.0%        7.000000
# 90%         10.000000
# 95%         18.000000
# max        218.000000
# Name: pastNday_order_num_on_siteId, dtype: float64
# [past_n_days_acc_alignment_num]
# 缺失率：0%
# count    99490.000000
# mean       456.024133
# std        285.294674
# min          0.000000
# 0%           0.000000
# 10%        116.000000
# 20%        218.000000
# 30.0%      298.000000
# 40%        368.000000
# 50%        432.000000
# 60.0%      499.000000
# 70%        572.000000
# 80%        660.000000
# 85.0%      718.000000
# 90%        789.000000
# 95%        915.000000
# max       2981.000000
# Name: past_n_days_acc_alignment_num, dtype: float64
# [past_n_days_acc_order_amount]
# 缺失率：0%
# count     99490.000000
# mean      29649.247071
# std       37245.938755
# min           0.000000
# 0%            0.000000
# 10%           0.000000
# 20%           0.000000
# 30.0%      3980.000000
# 40%       11080.000000
# 50%       17180.000000
# 60.0%     26260.000000
# 70%       36640.000000
# 80%       51440.000000
# 85.0%     61560.000000
# 90%       75640.000000
# 95%      100580.000000
# max      497046.000000
# Name: past_n_days_acc_order_amount, dtype: float64
# [past_n_days_acc_order_avg_amount]
# 缺失率：0%
# count    99490.000000
# mean      7666.192422
# std       6047.219481
# min          0.000000
# 0%           0.000000
# 10%          0.000000
# 20%          0.000000
# 30.0%     3580.000000
# 40%       7480.000000
# 50%       8546.670000
# 60.0%     9640.000000
# 70%      10890.000000
# 80%      12480.000000
# 85.0%    13385.000000
# 90%      14800.000000
# 95%      16425.000000
# max      70000.000000
# Name: past_n_days_acc_order_avg_amount, dtype: float64
# [past_n_days_acc_order_num]
# 缺失率：0%
# count    99490.000000
# mean         2.809519
# std          3.430078
# min          0.000000
# 0%           0.000000
# 10%          0.000000
# 20%          0.000000
# 30.0%        1.000000
# 40%          1.000000
# 50%          2.000000
# 60.0%        3.000000
# 70%          3.000000
# 80%          5.000000
# 85.0%        6.000000
# 90%          7.000000
# 95%          9.000000
# max         44.000000
# Name: past_n_days_acc_order_num, dtype: float64
# [past_n_days_acc_order_rate]
# 缺失率：0%
# count    99490.000000
# mean         0.129721
# std          0.151451
# min          0.000000
# 0%           0.000000
# 10%          0.000000
# 20%          0.000000
# 30.0%        0.034920
# 40%          0.056250
# 50%          0.088650
# 60.0%        0.122470
# 70%          0.164310
# 80%          0.221770
# 85.0%        0.261360
# 90%          0.319170
# 95%          0.418170
# max          2.429490
# Name: past_n_days_acc_order_rate, dtype: float64
# [recycle_opp_distribution_num]
# 缺失率：31%
# count    68776.000000
# mean         4.558116
# std          9.105076
# min          0.000000
# 0%           0.000000
# 10%          0.000000
# 20%          0.000000
# 30.0%        0.000000
# 40%          0.000000
# 50%          0.000000
# 60.0%        2.000000
# 70%          4.000000
# 80%          7.000000
# 85.0%       10.000000
# 90%         14.000000
# 95%         21.000000
# max        100.000000
# Name: recycle_opp_distribution_num, dtype: float64
# [recycle_opp_distribution_saturation]
# 缺失率：31%
# count    68537.000000
# mean         0.175434
# std          0.276358
# min          0.000000
# 0%           0.000000
# 10%          0.000000
# 20%          0.000000
# 30.0%        0.000000
# 40%          0.000000
# 50%          0.000000
# 60.0%        0.080000
# 70%          0.200000
# 80%          0.350000
# 85.0%        0.466700
# 90%          0.600000
# 95%          0.833300
# max          4.000000
# Name: recycle_opp_distribution_saturation, dtype: float64
# [recycle_opp_limit_num]
# 缺失率：31%
# count    68537.000000
# mean        28.779287
# std         22.536512
# min          1.000000
# 0%           1.000000
# 10%          5.000000
# 20%         10.000000
# 30.0%       15.000000
# 40%         20.000000
# 50%         30.000000
# 60.0%       30.000000
# 70%         30.000000
# 80%         35.000000
# 85.0%       50.000000
# 90%         60.000000
# 95%         80.000000
# max        100.000000
# Name: recycle_opp_limit_num, dtype: float64
# [timedelta_from]
# 缺失率：93%
# count    6778.000000
# mean       56.692004
# std        98.499976
# min         0.400000
# 0%          0.400000
# 10%         0.600000
# 20%         1.700000
# 30.0%       7.300000
# 40%        12.900000
# 50%        20.500000
# 60.0%      32.100000
# 70%        46.500000
# 80%        72.500000
# 85.0%      87.245000
# 90%       155.660000
# 95%       294.405000
# max       616.100000
# Name: timedelta_from, dtype: float64
# [today_unfollowed_num]
# 缺失率：0%
# count    99484.000000
# mean         8.281322
# std          9.092047
# min          0.000000
# 0%           0.000000
# 10%          1.000000
# 20%          2.000000
# 30.0%        3.000000
# 40%          4.000000
# 50%          6.000000
# 60.0%        8.000000
# 70%         10.000000
# 80%         13.000000
# 85.0%       15.000000
# 90%         19.000000
# 95%         25.000000
# max        117.000000
# Name: today_unfollowed_num, dtype: float64
# [valid_call_num]
# 缺失率：65%
# count    34799.000000
# mean         9.524871
# std         10.511594
# min          1.000000
# 0%           1.000000
# 10%          1.000000
# 20%          2.000000
# 30.0%        3.000000
# 40%          4.000000
# 50%          6.000000
# 60.0%        8.000000
# 70%         11.000000
# 80%         15.000000
# 85.0%       19.000000
# 90%         24.000000
# 95%         31.000000
# max        208.000000
# Name: valid_call_num, dtype: float64

# %%
for feature in cate_features:
    feature_value = df[feature]
    print("\n[%s]"%feature)
    print("缺失率：%.0f%%"%(feature_value.isna().sum()/n*100))
    value_counts = feature_value.value_counts()
    print("value_counts:{}".format(len(value_counts)))
    print(value_counts[:50])
    if len(value_counts)<20:
        sns.countplot(x=feature_value)
        plt.show()
    else:
        sns.violinplot(x = value_counts.values)
        plt.show()
# Out:
# [alignment_day]
# 缺失率：0%
# value_counts:31
# 22    4601
# 18    4175
# 17    4099
# 19    4081
# 16    4009
# 20    3953
# 24    3949
# 23    3839
# 9     3739
# 25    3730
# 10    3626
# 21    3541
# 11    3435
# 15    3343
# 28    3328
# 3     3212
# 12    3189
# 4     3187
# 26    3133
# 8     3055
# 5     3016
# 29    2983
# 13    2897
# 27    2780
# 14    2629
# 2     2626
# 6     2468
# 30    2147
# 7     2069
# 1     1723
# 31     928
# Name: alignment_day, dtype: int64
# [alignment_day_of_week]
# 缺失率：0%
# value_counts:7
# 2    18077
# 3    17437
# 4    16594
# 5    15281
# 6    13063
# 1    10003
# 7     9035
# Name: alignment_day_of_week, dtype: int64
# [alignment_hour]
# 缺失率：0%
# value_counts:16
# 9     26069
# 10    17015
# 11     9424
# 12     7878
# 13     7190
# 14     6481
# 15     6064
# 16     4884
# 17     4212
# 18     3300
# 19     2722
# 20     2069
# 21     1184
# 22      577
# 8       406
# 23       15
# Name: alignment_hour, dtype: int64
# [alignment_month]
# 缺失率：0%
# value_counts:5
# 7    23370
# 4    22273
# 6    21258
# 5    20134
# 3    12455
# Name: alignment_month, dtype: int64
# [alignment_year]
# 缺失率：0%
# value_counts:1
# 2019    99490
# Name: alignment_year, dtype: int64
# [consult_type]
# 缺失率：0%
# value_counts:3
# ALL       43039
# WECHAT    42663
# CALL      13788
# Name: consult_type, dtype: int64
# [contain_education_or_promotion_key_word_in_dialogue]
# 缺失率：100%
# value_counts:1
# 1.0    75
# Name: contain_education_or_promotion_key_word_in_dialogue, dtype: int64
# [contain_price_key_word_in_dialogue]
# 缺失率：100%
# value_counts:1
# 1.0    275
# Name: contain_price_key_word_in_dialogue, dtype: int64
# [create_user]
# 缺失率：0%
# value_counts:399
# studentInput        31978
# system               2619
# xs-lidan              643
# undefined             622
# gaoxuelian            606
# wanghan03             603
# gongjuyan-pq          600
# xiongchenchen         582
# wuyaqin13             573
# litianqi              572
# zhengting13           571
# dengjuan-pq           568
# zhaojinghui           567
# wangmeng13            567
# yangmeifeng01         565
# wangchang01           565
# chengzhenzhen10       563
# heyaqing              562
# pengwanqiu            561
# liujunchen            561
# xingmin01             546
# fangyingjie-pq        544
# yangna                541
# cengqingli            535
# wuqianqian            532
# litingting16          531
# huangfuxiaojie40      518
# lixiaoyao01           515
# liangpei              513
# wanqiao               510
# chenlong04            507
# chensujuan            506
# chenxuenan13          499
# daiqi01               498
# hezhenzhen            498
# xuxiaofang            494
# jiangpei01            494
# hetian                492
# wangmengdie           489
# tongna                489
# dengwen-pq            487
# daiyangmei01          487
# zuoqiutong01          485
# zhangyu03             484
# liujun-pq             484
# chengmiao-pq          481
# tanxi                 476
# wuhongxing-pq         475
# wangsha85             475
# yudan                 475
# Name: create_user, dtype: int64
# [dialogue_start_at]
# 缺失率：36%
# value_counts:6
# morning          21515
# noon             20967
# afternoon        14088
# night             6503
# deep_night         453
# early_morning       17
# Name: dialogue_start_at, dtype: int64
# [educationalBackground]
# 缺失率：3%
# value_counts:6
# 4.0    55105
# 3.0    27942
# 5.0    12447
# 2.0      701
# 6.0      616
# 1.0       48
# Name: educationalBackground, dtype: int64
# [first_proj_id]
# 缺失率：0%
# value_counts:14
# 32       72688
# 53       16287
# 63        3328
# 12        3326
# 10569     2928
# 21         623
# 13         222
# 10601       24
# 11          18
# 10609       17
# 62          14
# 23          12
# 52           2
# 10537        1
# Name: first_proj_id, dtype: int64
# [gender]
# 缺失率：2%
# value_counts:2
# M    56731
# F    40509
# Name: gender, dtype: int64
# [graduateSchool]
# 缺失率：3%
# value_counts:3379
# 武汉职业技术学院            1966
# 武汉工程职业技术学院         871
# 武汉生物工程学院             743
# 湖北科技职业学院             685
# 武汉城市职业学院             669
# 汉口学院                     646
# 长江职业学院                 626
# 武汉软件工程职业学院         571
# 武汉交通职业学院             561
# 武汉工程大学                 559
# 湖北交通职业技术学院         468
# 湖北第二师范学院             468
# 武汉商贸职业学院             461
# 武汉纺织大学                 459
# 国家开放大学                 456
# 华中师范大学                 442
# 黄冈职业技术学院             427
# 武汉科技大学                 422
# 长江大学                     418
# 武昌职业学院                 417
# 武汉大学                     405
# 武汉工商学院                 403
# 湖北职业技术学院             397
# 武汉信息传播职业技术学院     385
# 广州科技职业技术学院         360
# 广东农工商职业技术学院       354
# 武汉科技大学城市学院         348
# 武汉东湖学院                 346
# 广东岭南职业技术学院         345
# 武汉理工大学                 340
# 湖北经济学院                 339
# 武汉华夏理工学院             333
# 湖北工业大学                 326
# 湖北生态工程职业技术学院     325
# 湖北三峡职业技术学院         321
# 长江工程职业技术学院         316
# 武汉商学院                   316
# 武昌理工学院                 308
# 武汉船舶职业技术学院         300
# 河北农业大学                 291
# 湖北商贸学院                 289
# 广东工贸职业技术学院         278
# 中南民族大学                 278
# 广州华夏职业学院             265
# 江汉大学                     265
# 广东松山职业技术学院         262
# 湖北工业职业技术学院         262
# 武汉外语外事职业学院         259
# 武汉航海职业技术学院         253
# 承德石油高等专科学校         253
# Name: graduateSchool, dtype: int64
# [major]
# 缺失率：9%
# value_counts:1479
# 市场营销                  5268
# 无                        5170
# 电子商务                  3588
# 会计                      2718
# 文科                      1893
# 工商企业管理              1835
# 工商管理                  1802
# 机电一体化                1635
# 物流管理                  1457
# 商务英语                  1400
# 国际经济与贸易            1331
# 计算机                    1200
# 行政管理                  1147
# 计算机应用技术            1050
# 建筑工程技术              1045
# 财务管理                  1043
# 学前教育                   920
# 酒店管理                   874
# 汽车检测与维修             848
# 人力资源管理               826
# 旅游管理                   809
# 工程造价                   792
# 软件技术                   746
# 会计电算化                 740
# 电子信息工程               689
# 计算机应用                 686
# 理科                       674
# 会计学                     619
# 计算机网络技术             613
# 计算机科学与技术           611
# 艺术设计                   590
# 软件工程                   571
# 土木工程                   562
# 护理                       533
# 英语                       494
# 电气自动化                 476
# 机电一体化技术             475
# 机械制造与自动化           454
# 服装设计                   435
# 汽车检测与维修技术         427
# 金融学                     423
# 数控技术                   405
# 汽车技术服务与营销         402
# 模具设计与制造             394
# 连锁经营管理               377
# 工程管理                   369
# 计算机网络                 352
# 商务管理                   332
# 机械设计制造及其自动化     315
# 环境艺术设计               298
# Name: major, dtype: int64
# [marriageState]
# 缺失率：2%
# value_counts:4
# 1.0    89075
# 4.0     5456
# 3.0     2402
# 2.0      212
# Name: marriageState, dtype: int64
# [nationalEdu]
# 缺失率：3%
# value_counts:2
# 1.0    79389
# 2.0    17470
# Name: nationalEdu, dtype: int64
# [oppor_source]
# 缺失率：0%
# value_counts:22
# ONLINE_CS_GREATBEAR             63697
# MESSAGE_NEW_INSERT              32600
# MESSAGE_NEW_INSERT_3              897
# MESSAGE_NEW_INSERT_9              547
# MESSAGE_DELAY_ALLO_INSERT         287
# MESSAGE_DELAY_ALLO_INSERT_B       271
# MESSAGE_lite_app                  248
# ONLINE_CS_ROBOT_INDEPENDENT       205
# ONLINE_CS_SUNLANDS-ZLCX           157
# MESSAGE_APP                       144
# MESSAGE_APP_FREE_FLOW_INSERT      127
# MESSAGE_NEW_INSERT_8              116
# ONLINE_CS_NEWDRAGNET               53
# MESSAGE_APP_FLOW_INSERT            42
# MESSAGE_DELAY_ALLO_INSERT_A        32
# MESSAGE_CS_NEWDRAGNET_BATCH        26
# ONLINE_CS_ROBOT                    21
# message_app                         6
# MESSAGE_CS_GREATBEAR                6
# MESSAGE_NEW_INSERT_11               6
# MESSAGE_CMS_INSERT                  1
# ONLINE_CS_16BIT                     1
# Name: oppor_source, dtype: int64
# [posLevel]
# 缺失率：2%
# value_counts:9
# 1.0     93406
# 0.0      1163
# 2.0      1129
# 3.0      1089
# 4.0       288
# 18.0       21
# 5.0        20
# 11.0        9
# 17.0        7
# Name: posLevel, dtype: int64
# [promotion_type]
# 缺失率：0%
# value_counts:5
# APP      69863
# SEM      18713
# DSP       8133
# OTHER     2610
# None       171
# Name: promotion_type, dtype: int64
# [quantum_id]
# 缺失率：0%
# value_counts:113
# 2030006    3810
# 2100865    3519
# 2030201    3183
# 2030016    3178
# 2030195    2950
# 2030205    2878
# 2030102    2843
# 2030104    2736
# 2030197    2706
# 2030038    2642
# 2030007    2482
# 2101269    2325
# 2100866    2060
# 2030034    1988
# 2100423    1946
# 2030001    1905
# 2030094    1875
# 2030212    1852
# 2100424    1847
# 2030107    1824
# 2100870    1694
# 2030088    1662
# 2030211    1594
# 2030222    1579
# 2030223    1561
# 2030112    1519
# 2030009    1444
# 2101271    1394
# 2030108    1391
# 2100867    1341
# 2030225    1238
# 2030109    1236
# 2030203    1186
# 2030216    1163
# 2030220    1063
# 2030004    1060
# 2030110    1031
# 2101408    1013
# 2030214    1007
# 2030218     974
# 2100873     967
# 2030186     920
# 2030204     901
# 2030196     869
# 2030111     865
# 2030199     848
# 2030228     770
# 2101386     760
# 2030185     741
# 2030217     735
# Name: quantum_id, dtype: int64
# [race]
# 缺失率：2%
# value_counts:27
# 汉          92354
# 满           1587
# 土家         1175
# 蒙古          431
# 苗            355
# 回            335
# 壮            245
# 布依          140
# 侗             95
# 彝             78
# 朝鲜           53
# 瑶             51
# 畲             44
# 乌孜别克       42
# 锡伯           39
# 维吾尔         38
# 白             36
# 水             35
# 哈尼           33
# 哈萨克         22
# 藏             16
# 高山            5
# 达斡尔          4
# 仫佬            4
# 毛南            3
# 景颇            1
# 黎              1
# Name: race, dtype: int64
# [residenceType]
# 缺失率：3%
# value_counts:6
# 4.0    60807
# 3.0    18191
# 2.0     8779
# 1.0     8143
# 6.0      276
# 5.0       10
# Name: residenceType, dtype: int64
# [site_source]
# 缺失率：0%
# value_counts:252
# 微信朋友圈移动平台              11555
# 百度搜索搜索                    10214
# 今日头条网盟                     8597
# 微信朋友圈微信                   7372
# 腾讯广点通广点通                 6947
# 360网盟网盟                      6450
# 腾讯广点通搜索                   4387
# 今日头条搜索                     3776
# 今日头条极速APP下载              3205
# 腾讯广点通极速APP下载            2854
# 腾讯广点通网盟                   2795
# 搜狗搜索搜索                     2639
# 360搜索搜索                      2565
# 神马搜索搜索                     1997
# app下载无归属录入极速APP下载     1413
# 百度Feeds流网盟                  1344
# 360网盟移动平台                  1245
# 今日头条移动平台                 1155
# 百度Feeds流搜索                  1015
# 360网盟导航                       958
# 微信朋友圈网盟                    896
# 今日头条导航                      783
# 腾讯广点通导航                    740
# 百度搜索移动平台                  736
# 百度品专搜索                      594
# 腾讯广点通APP下载                 552
# 主APP无归属录入未知               535
# 腾讯广点通SEO                     532
# 今日头条头条信息流                501
# 微信朋友圈搜索                    489
# 微信朋友圈广点通                  429
# 今日头条SEO                       402
# 微信朋友圈导航                    375
# 今日头条APP下载                   365
# 快手搜索                          350
# 腾讯广点通留言                    347
# 今日头条微信                      326
# 腾讯广点通微信                    315
# 快手网盟                          304
# 微信朋友圈SEO                     303
# app下载无归属录入APP下载          292
# 360移动推广极速APP下载            278
# 腾讯广点通天猫                    260
# 今日头条DSP                       255
# 百度Feeds流SEO                    250
# ASO主APP下载                      222
# 腾讯广点通移动平台                213
# 腾讯广点通DSP                     207
# 360网盟地推                       204
# 360网盟搜索                       203
# Name: site_source, dtype: int64
# [student_cellphone_midnum]
# 缺失率：44%
# value_counts:9821
# 998.0     28
# 997.0     25
# 9917.0    24
# 990.0     23
# 908.0     22
# 995.0     21
# 105.0     20
# 1003.0    20
# 2115.0    20
# 903.0     19
# 9531.0    19
# 1017.0    19
# 524.0     19
# 9721.0    18
# 2141.0    18
# 2123.0    18
# 1115.0    18
# 514.0     18
# 103.0     18
# 1109.0    18
# 2160.0    17
# 972.0     17
# 2121.0    17
# 5679.0    17
# 9909.0    17
# 9509.0    17
# 9922.0    17
# 9920.0    17
# 2100.0    17
# 526.0     17
# 994.0     17
# 1073.0    17
# 108.0     17
# 121.0     17
# 120.0     17
# 1052.0    17
# 119.0     17
# 1098.0    17
# 2179.0    17
# 1060.0    16
# 661.0     16
# 9928.0    16
# 5678.0    16
# 9925.0    16
# 2110.0    16
# 9978.0    16
# 2574.0    16
# 9913.0    16
# 1981.0    16
# 9911.0    16
# Name: student_cellphone_midnum, dtype: int64
# [twice_consult]
# 缺失率：90%
# value_counts:1
# 1.0    10406
# Name: twice_consult, dtype: int64

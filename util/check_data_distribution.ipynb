# %%
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)
pd.set_option('display.unicode.ambiguous_as_wide', True)
pd.set_option('display.unicode.east_asian_width', True)
np.set_printoptions(threshold=np.inf)
plt.rcParams['font.sans-serif'] = ['SimHei']  # 中文字体设置-黑体
plt.rcParams['axes.unicode_minus'] = False  # 解决保存图像是负号'-'显示为方块的问题
sns.set(font='SimHei')  # 解决Seaborn中文显示问题


# %matplotlib inline
sns.set(style="whitegrid")

cate_features =['alignment_day', 'alignment_day_of_week', 'alignment_hour', 'alignment_month', 'alignment_year', 'consult_type', 'contain_education_or_promotion_key_word_in_dialogue', 'contain_price_key_word_in_dialogue', 'create_user', 'dialogue_start_at', 'educationalBackground', 'first_proj_id', 'gender', 'graduateSchool', 'major', 'marriageState', 'nationalEdu', 'oppor_source', 'posLevel', 'promotion_type', 'quantum_id', 'race', 'residenceType', 'site_source', 'student_cellphone_midnum', 'twice_consult']
cont_features = ['account_age', 'all_call_num', 'avgerage_waiting_time_of_dialogue', 'delta_days_from_entryDate', 'delta_time_of_create_time_and_operator_time', 'duration_of_dialogue', 'message_opp_distribution_num', 'message_opp_distribution_saturation', 'message_opp_limit_num', 'number_of_dialogue', 'number_of_student_dialogue', 'online_opp_distribution_num', 'online_opp_distribution_saturation', 'online_opp_limit_num', 'opp_completed_rate', 'opp_following_num', 'opp_today_following_num', 'pastNday_advertiser_applied_ratio', 'pastNday_advertiser_distribution_num', 'pastNday_advertiser_order_num', 'pastNday_applied_ratio_on_siteId', 'pastNday_distribution_num_on_siteId', 'pastNday_order_num_on_siteId', 'past_n_days_acc_alignment_num', 'past_n_days_acc_order_amount', 'past_n_days_acc_order_avg_amount', 'past_n_days_acc_order_num', 'past_n_days_acc_order_rate', 'recycle_opp_distribution_num', 'recycle_opp_distribution_saturation', 'recycle_opp_limit_num', 'timedelta_from', 'today_unfollowed_num', 'valid_call_num']
csv_features = ['label', 'account_age', 'alignment_day', 'alignment_day_of_week', 'alignment_hour', 'alignment_month', 'alignment_year', 'all_call_num', 'avgerage_waiting_time_of_dialogue', 'consult_type', 'contain_education_or_promotion_key_word_in_dialogue', 'contain_price_key_word_in_dialogue', 'create_user', 'delta_days_from_entryDate', 'delta_time_of_create_time_and_operator_time', 'dialogue_start_at', 'duration_of_dialogue', 'educationalBackground', 'first_proj_id', 'gender', 'graduateSchool', 'major', 'marriageState', 'message_opp_distribution_num', 'message_opp_distribution_saturation', 'message_opp_limit_num', 'nationalEdu', 'number_of_dialogue', 'number_of_student_dialogue', 'online_opp_distribution_num', 'online_opp_distribution_saturation', 'online_opp_limit_num', 'opp_completed_rate', 'opp_following_num', 'opp_today_following_num', 'oppor_source', 'pastNday_advertiser_applied_ratio', 'pastNday_advertiser_distribution_num', 'pastNday_advertiser_order_num', 'pastNday_applied_ratio_on_siteId', 'pastNday_distribution_num_on_siteId', 'pastNday_order_num_on_siteId', 'past_n_days_acc_alignment_num', 'past_n_days_acc_order_amount', 'past_n_days_acc_order_avg_amount', 'past_n_days_acc_order_num', 'past_n_days_acc_order_rate', 'posLevel', 'promotion_type', 'quantum_id', 'race', 'recycle_opp_distribution_num', 'recycle_opp_distribution_saturation', 'recycle_opp_limit_num', 'residenceType', 'site_source', 'student_cellphone_midnum', 'student_dialogue_fenci', 'timedelta_from', 'today_unfollowed_num', 'twice_consult', 'valid_call_num']

csv_file = "E:\project_data\Test\\train_csv_feature_sample"

df = pd.read_csv(csv_file)
df.columns = csv_features

feature_ls  = list([(x,'category') for x in ["label"]+cate_features]+[(x,float) for x in cont_features])
dtypes = dict(feature_ls)
df = df.astype(dtypes)
n = len(df)
# df.dtypes

# %%
for feature in cont_features:
    feature_value = df[feature]
    print("[%s]"%feature)
    print("缺失率：%.0f%%"%(feature_value.isna().sum()/n*100))
    percentiles = list(np.arange(8)*0.1)+list(np.arange(8,10,0.5)*0.1)
    print(feature_value.describe(percentiles=percentiles))
    sns.violinplot(x=feature_value)
    plt.show()
# Out:
# [account_age]
# 缺失率：0%
# count    9999.000000
# mean       24.330933
# std         3.061155
# min        17.000000
# 0%         17.000000
# 10%        21.000000
# 20%        22.000000
# 30.0%      22.000000
# 40%        23.000000
# 50%        24.000000
# 60.0%      25.000000
# 70%        26.000000
# 80%        27.000000
# 85.0%      28.000000
# 90%        29.000000
# 95%        30.000000
# max        38.000000
# Name: account_age, dtype: float64
# [all_call_num]
# 缺失率：45%
# count    5465.000000
# mean       53.496615
# std        58.385668
# min         1.000000
# 0%          1.000000
# 10%         2.000000
# 20%         6.000000
# 30.0%      12.000000
# 40%        20.000000
# 50%        32.000000
# 60.0%      47.000000
# 70%        67.800000
# 80%        95.000000
# 85.0%     115.000000
# 90%       137.000000
# 95%       169.000000
# max       503.000000
# Name: all_call_num, dtype: float64
# [avgerage_waiting_time_of_dialogue]
# 缺失率：56%
# count    4403.000000
# mean        8.950943
# std        22.967340
# min         1.000000
# 0%          1.000000
# 10%         5.000000
# 20%         5.000000
# 30.0%       6.000000
# 40%         6.000000
# 50%         7.000000
# 60.0%       8.000000
# 70%         9.000000
# 80%        10.000000
# 85.0%      11.000000
# 90%        13.000000
# 95%        16.000000
# max      1370.000000
# Name: avgerage_waiting_time_of_dialogue, dtype: float64
# [delta_days_from_entryDate]
# 缺失率：6%
# count    9444.000000
# mean      251.298073
# std       249.498999
# min         2.000000
# 0%          2.000000
# 10%        28.000000
# 20%        42.000000
# 30.0%      55.000000
# 40%       130.000000
# 50%       179.000000
# 60.0%     249.000000
# 70%       357.000000
# 80%       405.000000
# 85.0%     487.000000
# 90%       565.000000
# 95%       718.000000
# max      1891.000000
# Name: delta_days_from_entryDate, dtype: float64
# [delta_time_of_create_time_and_operator_time]
# 缺失率：0%
# count    9.999000e+03
# mean     4.884768e+05
# std      1.140875e+06
# min      1.500000e+01
# 0%       1.500000e+01
# 10%      3.600000e+01
# 20%      4.300000e+01
# 30.0%    4.900000e+01
# 40%      6.800000e+01
# 50%      8.600000e+02
# 60.0%    6.668400e+03
# 70%      4.448760e+04
# 80%      7.091206e+05
# 85.0%    1.303553e+06
# 90%      1.519480e+06
# 95%      3.103590e+06
# max      7.582646e+06
# Name: delta_time_of_create_time_and_operator_time, dtype: float64
# [duration_of_dialogue]
# 缺失率：56%
# count     4403.000000
# mean       125.946400
# std        249.798183
# min          7.000000
# 0%           7.000000
# 10%         56.000000
# 20%         65.000000
# 30.0%       74.000000
# 40%         83.000000
# 50%         92.000000
# 60.0%      105.000000
# 70%        120.000000
# 80%        145.000000
# 85.0%      166.000000
# 90%        196.800000
# 95%        265.900000
# max      13697.000000
# Name: duration_of_dialogue, dtype: float64
# [message_opp_distribution_num]
# 缺失率：3%
# count    9721.000000
# mean        3.674416
# std         4.536234
# min         0.000000
# 0%          0.000000
# 10%         0.000000
# 20%         1.000000
# 30.0%       1.000000
# 40%         2.000000
# 50%         2.000000
# 60.0%       3.000000
# 70%         4.000000
# 80%         6.000000
# 85.0%       7.000000
# 90%         8.000000
# 95%        12.000000
# max        41.000000
# Name: message_opp_distribution_num, dtype: float64
# [message_opp_distribution_saturation]
# 缺失率：3%
# count    9706.000000
# mean        0.202280
# std         0.205334
# min         0.000000
# 0%          0.000000
# 10%         0.000000
# 20%         0.035700
# 30.0%       0.066700
# 40%         0.100000
# 50%         0.133300
# 60.0%       0.200000
# 70%         0.250000
# 80%         0.346200
# 85.0%       0.400000
# 90%         0.500000
# 95%         0.625000
# max         1.150000
# Name: message_opp_distribution_saturation, dtype: float64
# [message_opp_limit_num]
# 缺失率：3%
# count    9706.000000
# mean       19.714300
# std        11.262686
# min         1.000000
# 0%          1.000000
# 10%         7.000000
# 20%        10.000000
# 30.0%      13.000000
# 40%        15.000000
# 50%        16.000000
# 60.0%      22.000000
# 70%        25.000000
# 80%        28.000000
# 85.0%      30.000000
# 90%        40.000000
# 95%        40.000000
# max       100.000000
# Name: message_opp_limit_num, dtype: float64
# [number_of_dialogue]
# 缺失率：56%
# count    4403.000000
# mean       14.796957
# std         3.012864
# min         4.000000
# 0%          4.000000
# 10%        12.000000
# 20%        13.000000
# 30.0%      13.000000
# 40%        14.000000
# 50%        14.000000
# 60.0%      15.000000
# 70%        16.000000
# 80%        17.000000
# 85.0%      17.000000
# 90%        18.000000
# 95%        20.000000
# max        44.000000
# Name: number_of_dialogue, dtype: float64
# [number_of_student_dialogue]
# 缺失率：56%
# count    4403.000000
# mean        4.383829
# std         1.201934
# min         1.000000
# 0%          1.000000
# 10%         3.000000
# 20%         4.000000
# 30.0%       4.000000
# 40%         4.000000
# 50%         4.000000
# 60.0%       4.000000
# 70%         5.000000
# 80%         5.000000
# 85.0%       5.000000
# 90%         6.000000
# 95%         6.000000
# max        19.000000
# Name: number_of_student_dialogue, dtype: float64
# [online_opp_distribution_num]
# 缺失率：2%
# count    9817.000000
# mean        2.447082
# std         2.599816
# min         0.000000
# 0%          0.000000
# 10%         0.000000
# 20%         0.000000
# 30.0%       1.000000
# 40%         1.000000
# 50%         2.000000
# 60.0%       2.000000
# 70%         3.000000
# 80%         4.000000
# 85.0%       5.000000
# 90%         6.000000
# 95%         8.000000
# max        16.000000
# Name: online_opp_distribution_num, dtype: float64
# [online_opp_distribution_saturation]
# 缺失率：2%
# count    9813.000000
# mean        0.159580
# std         0.166018
# min         0.000000
# 0%          0.000000
# 10%         0.000000
# 20%         0.000000
# 30.0%       0.050000
# 40%         0.083300
# 50%         0.120000
# 60.0%       0.166700
# 70%         0.200000
# 80%         0.280000
# 85.0%       0.333300
# 90%         0.333300
# 95%         0.454500
# max         1.000000
# Name: online_opp_distribution_saturation, dtype: float64
# [online_opp_limit_num]
# 缺失率：2%
# count    9813.000000
# mean       18.737287
# std        11.655158
# min         1.000000
# 0%          1.000000
# 10%         5.000000
# 20%        10.000000
# 30.0%      10.000000
# 40%        15.000000
# 50%        15.000000
# 60.0%      20.000000
# 70%        23.000000
# 80%        27.000000
# 85.0%      30.000000
# 90%        35.000000
# 95%        40.000000
# max       100.000000
# Name: online_opp_limit_num, dtype: float64
# [opp_completed_rate]
# 缺失率：54%
# count    4598.000000
# mean        0.293184
# std         0.181030
# min         0.037000
# 0%          0.037000
# 10%         0.100000
# 20%         0.142900
# 30.0%       0.181800
# 40%         0.214300
# 50%         0.250000
# 60.0%       0.307700
# 70%         0.352900
# 80%         0.428600
# 85.0%       0.500000
# 90%         0.500000
# 95%         0.625000
# max         1.000000
# Name: opp_completed_rate, dtype: float64
# [opp_following_num]
# 缺失率：23%
# count    7685.000000
# mean        9.870917
# std        11.426370
# min         1.000000
# 0%          1.000000
# 10%         1.000000
# 20%         2.000000
# 30.0%       3.000000
# 40%         5.000000
# 50%         6.000000
# 60.0%       8.000000
# 70%        11.000000
# 80%        16.000000
# 85.0%      19.000000
# 90%        24.000000
# 95%        31.000000
# max       371.000000
# Name: opp_following_num, dtype: float64
# [opp_today_following_num]
# 缺失率：54%
# count    4598.000000
# mean        3.331666
# std         2.882486
# min         1.000000
# 0%          1.000000
# 10%         1.000000
# 20%         1.000000
# 30.0%       2.000000
# 40%         2.000000
# 50%         2.000000
# 60.0%       3.000000
# 70%         4.000000
# 80%         5.000000
# 85.0%       6.000000
# 90%         7.000000
# 95%         9.000000
# max        24.000000
# Name: opp_today_following_num, dtype: float64
# [pastNday_advertiser_applied_ratio]
# 缺失率：0%
# count    9999.000000
# mean        0.004293
# std         0.004163
# min         0.000000
# 0%          0.000000
# 10%         0.002000
# 20%         0.002000
# 30.0%       0.002000
# 40%         0.002000
# 50%         0.002000
# 60.0%       0.003600
# 70%         0.003600
# 80%         0.006200
# 85.0%       0.009600
# 90%         0.011200
# 95%         0.011200
# max         0.036900
# Name: pastNday_advertiser_applied_ratio, dtype: float64
# [pastNday_advertiser_distribution_num]
# 缺失率：0%
# count      9999.000000
# mean     334493.638864
# std      181759.702297
# min         116.000000
# 0%          116.000000
# 10%       50315.000000
# 20%      163231.000000
# 30.0%    252163.000000
# 40%      252163.000000
# 50%      327652.000000
# 60.0%    525379.000000
# 70%      525379.000000
# 80%      525379.000000
# 85.0%    525379.000000
# 90%      525379.000000
# 95%      525379.000000
# max      525379.000000
# Name: pastNday_advertiser_distribution_num, dtype: float64
# [pastNday_advertiser_order_num]
# 缺失率：0%
# count    9999.000000
# mean      965.199320
# std       425.652124
# min         0.000000
# 0%          0.000000
# 10%       355.000000
# 20%       510.000000
# 30.0%     739.000000
# 40%      1056.000000
# 50%      1056.000000
# 60.0%    1056.000000
# 70%      1056.000000
# 80%      1167.000000
# 85.0%    1167.000000
# 90%      1824.000000
# 95%      1824.000000
# max      1824.000000
# Name: pastNday_advertiser_order_num, dtype: float64
# [pastNday_applied_ratio_on_siteId]
# 缺失率：1%
# count    9904.000000
# mean        0.096615
# std         0.129817
# min         0.000000
# 0%          0.000000
# 10%         0.000000
# 20%         0.000000
# 30.0%       0.000000
# 40%         0.028490
# 50%         0.060410
# 60.0%       0.083260
# 70%         0.108030
# 80%         0.166090
# 85.0%       0.199780
# 90%         0.234440
# 95%         0.416980
# max         1.414210
# Name: pastNday_applied_ratio_on_siteId, dtype: float64
# [pastNday_distribution_num_on_siteId]
# 缺失率：1%
# count    9904.000000
# mean      723.689822
# std       917.410545
# min         1.000000
# 0%          1.000000
# 10%        46.000000
# 20%       108.600000
# 30.0%     180.000000
# 40%       271.000000
# 50%       390.000000
# 60.0%     673.000000
# 70%       833.000000
# 80%      1096.000000
# 85.0%    1248.000000
# 90%      1522.000000
# 95%      2650.000000
# max      5712.000000
# Name: pastNday_distribution_num_on_siteId, dtype: float64
# [pastNday_order_num_on_siteId]
# 缺失率：1%
# count    9904.000000
# mean        2.951636
# std         4.708013
# min         0.000000
# 0%          0.000000
# 10%         0.000000
# 20%         0.000000
# 30.0%       0.000000
# 40%         1.000000
# 50%         1.000000
# 60.0%       2.000000
# 70%         3.000000
# 80%         5.000000
# 85.0%       6.000000
# 90%         7.000000
# 95%        13.000000
# max        24.000000
# Name: pastNday_order_num_on_siteId, dtype: float64
# [past_n_days_acc_alignment_num]
# 缺失率：0%
# count    9999.000000
# mean      440.047305
# std       194.869208
# min         0.000000
# 0%          0.000000
# 10%       169.000000
# 20%       279.000000
# 30.0%     339.000000
# 40%       398.000000
# 50%       443.000000
# 60.0%     483.000000
# 70%       544.000000
# 80%       613.000000
# 85.0%     655.000000
# 90%       697.000000
# 95%       760.000000
# max       939.000000
# Name: past_n_days_acc_alignment_num, dtype: float64
# [past_n_days_acc_order_amount]
# 缺失率：0%
# count      9999.000000
# mean      24127.233093
# std       25442.625548
# min           0.000000
# 0%            0.000000
# 10%           0.000000
# 20%           0.000000
# 30.0%      7480.000000
# 40%       12480.000000
# 50%       16800.000000
# 60.0%     23600.000000
# 70%       31580.000000
# 80%       45200.000000
# 85.0%     52860.000000
# 90%       62040.000000
# 95%       72500.000000
# max      138540.000000
# Name: past_n_days_acc_order_amount, dtype: float64
# [past_n_days_acc_order_avg_amount]
# 缺失率：0%
# count     9999.000000
# mean      7702.842162
# std       5405.144915
# min          0.000000
# 0%           0.000000
# 10%          0.000000
# 20%          0.000000
# 30.0%     5980.000000
# 40%       7980.000000
# 50%       8890.000000
# 60.0%     9605.000000
# 70%      10644.000000
# 80%      12300.000000
# 85.0%    12800.000000
# 90%      13800.000000
# 95%      15520.000000
# max      23600.000000
# Name: past_n_days_acc_order_avg_amount, dtype: float64
# [past_n_days_acc_order_num]
# 缺失率：0%
# count    9999.000000
# mean        2.282728
# std         2.327715
# min         0.000000
# 0%          0.000000
# 10%         0.000000
# 20%         0.000000
# 30.0%       1.000000
# 40%         1.000000
# 50%         2.000000
# 60.0%       2.000000
# 70%         3.000000
# 80%         4.000000
# 85.0%       5.000000
# 90%         6.000000
# 95%         7.000000
# max        12.000000
# Name: past_n_days_acc_order_num, dtype: float64
# [past_n_days_acc_order_rate]
# 缺失率：0%
# count    9999.000000
# mean        0.106983
# std         0.108195
# min         0.000000
# 0%          0.000000
# 10%         0.000000
# 20%         0.000000
# 30.0%       0.038580
# 40%         0.051500
# 50%         0.082270
# 60.0%       0.103140
# 70%         0.149260
# 80%         0.191190
# 85.0%       0.222493
# 90%         0.257010
# 95%         0.302292
# max         0.641430
# Name: past_n_days_acc_order_rate, dtype: float64
# [recycle_opp_distribution_num]
# 缺失率：26%
# count    7432.000000
# mean        2.798170
# std         4.377726
# min         0.000000
# 0%          0.000000
# 10%         0.000000
# 20%         0.000000
# 30.0%       0.000000
# 40%         0.000000
# 50%         1.000000
# 60.0%       2.000000
# 70%         2.000000
# 80%         5.000000
# 85.0%       7.000000
# 90%        10.000000
# 95%        13.000000
# max        24.000000
# Name: recycle_opp_distribution_num, dtype: float64
# [recycle_opp_distribution_saturation]
# 缺失率：26%
# count    7421.000000
# mean        0.218942
# std         0.316021
# min         0.000000
# 0%          0.000000
# 10%         0.000000
# 20%         0.000000
# 30.0%       0.000000
# 40%         0.000000
# 50%         0.033300
# 60.0%       0.066700
# 70%         0.266700
# 80%         0.533300
# 85.0%       0.650000
# 90%         0.760000
# 95%         0.950000
# max         1.000000
# Name: recycle_opp_distribution_saturation, dtype: float64
# [recycle_opp_limit_num]
# 缺失率：26%
# count    7421.000000
# mean       21.278669
# std        17.371181
# min         1.000000
# 0%          1.000000
# 10%         3.000000
# 20%         6.000000
# 30.0%      10.000000
# 40%        15.000000
# 50%        20.000000
# 60.0%      20.000000
# 70%        30.000000
# 80%        30.000000
# 85.0%      30.000000
# 90%        60.000000
# 95%        60.000000
# max       100.000000
# Name: recycle_opp_limit_num, dtype: float64
# [timedelta_from]
# 缺失率：91%
# count    898.000000
# mean      25.904232
# std       67.723886
# min        0.400000
# 0%         0.400000
# 10%        0.400000
# 20%        0.500000
# 30.0%      0.700000
# 40%        1.500000
# 50%        8.400000
# 60.0%     12.020000
# 70%       16.390000
# 80%       21.100000
# 85.0%     24.200000
# 90%       49.890000
# 95%      133.485000
# max      524.900000
# Name: timedelta_from, dtype: float64
# [today_unfollowed_num]
# 缺失率：0%
# count    9999.000000
# mean        6.522552
# std         5.712249
# min         0.000000
# 0%          0.000000
# 10%         0.000000
# 20%         1.000000
# 30.0%       3.000000
# 40%         4.000000
# 50%         5.000000
# 60.0%       7.000000
# 70%         9.000000
# 80%        11.000000
# 85.0%      12.000000
# 90%        14.000000
# 95%        17.000000
# max        36.000000
# Name: today_unfollowed_num, dtype: float64
# [valid_call_num]
# 缺失率：49%
# count    5066.000000
# mean       12.461705
# std        11.988931
# min         1.000000
# 0%          1.000000
# 10%         1.000000
# 20%         2.000000
# 30.0%       4.000000
# 40%         6.000000
# 50%         8.500000
# 60.0%      11.000000
# 70%        15.000000
# 80%        21.000000
# 85.0%      26.000000
# 90%        30.000000
# 95%        36.000000
# max        85.000000
# Name: valid_call_num, dtype: float64

# %%
for feature in cate_features:
    feature_value = df[feature]
    print("\n[%s]"%feature)
    print("缺失率：%.0f%%"%(feature_value.isna().sum()/n*100))
    value_counts = feature_value.value_counts()
    print("value_counts:{}".format(len(value_counts)))
    print(value_counts[:50])
    if len(value_counts)<20:
        sns.countplot(x=feature_value)
        plt.show()
    else:
        sns.violinplot(x = value_counts.values)
        plt.show()
# Out:
# [alignment_day]
# 缺失率：0%
# value_counts:1
# 26    9999
# Name: alignment_day, dtype: int64
# [alignment_day_of_week]
# 缺失率：0%
# value_counts:1
# 6    9999
# Name: alignment_day_of_week, dtype: int64
# [alignment_hour]
# 缺失率：0%
# value_counts:15
# 9     2296
# 10    1344
# 11     894
# 13     840
# 12     744
# 15     683
# 14     641
# 18     506
# 16     461
# 17     443
# 19     383
# 20     382
# 21     212
# 22     138
# 8       32
# Name: alignment_hour, dtype: int64
# [alignment_month]
# 缺失率：0%
# value_counts:1
# 4    9999
# Name: alignment_month, dtype: int64
# [alignment_year]
# 缺失率：0%
# value_counts:1
# 2019    9999
# Name: alignment_year, dtype: int64
# [consult_type]
# 缺失率：0%
# value_counts:3
# WECHAT    3736
# CALL      3141
# ALL       3122
# Name: consult_type, dtype: int64
# [contain_education_or_promotion_key_word_in_dialogue]
# 缺失率：100%
# value_counts:1
# 1.0    4
# Name: contain_education_or_promotion_key_word_in_dialogue, dtype: int64
# [contain_price_key_word_in_dialogue]
# 缺失率：100%
# value_counts:1
# 1.0    12
# Name: contain_price_key_word_in_dialogue, dtype: int64
# [create_user]
# 缺失率：0%
# value_counts:183
# studentInput        5578
# gongjuyan-pq         133
# liujunchen           128
# fangyingjie-pq       122
# zhaojinghui          118
# dengjuan-pq          117
# yangmeifeng01        110
# wangyue15            105
# zhangxiang24          98
# panting-pq            95
# tanxi                 94
# liuying81             92
# dengyalan-pq          91
# chenzhen03-pq         85
# wangsha85             77
# chenhong-pq           76
# yudan                 74
# mengdan-pq            71
# wuhongxing-pq         70
# linshaojun-pq         69
# wanglinfeng           68
# chenliwen             67
# chengxi               66
# sutingting-pq         63
# weifengjiao           60
# xuxiaoqin-pq          60
# wangzhonghua-pq       59
# pengying-pq           58
# songling85            56
# weiyuxia-pq           54
# hetingting            51
# yanglan-pq            50
# liqingping-pq         49
# wanglu85              45
# xiongchenchen         45
# wuhao                 45
# zhangyue02            43
# dengqin-pq            42
# wangchang01           41
# qishiyu               41
# liujun-pq             41
# kuangshanshan-pq      41
# chenxuenan13          39
# wangmengdie           38
# dongyuanhong12        37
# zhoujinhong           37
# hetian                36
# pengwanqiu            36
# peimeijun             35
# sunshan               34
# Name: create_user, dtype: int64
# [dialogue_start_at]
# 缺失率：56%
# value_counts:6
# noon             1332
# morning          1239
# afternoon        1115
# night             650
# deep_night         65
# early_morning       2
# Name: dialogue_start_at, dtype: int64
# [educationalBackground]
# 缺失率：1%
# value_counts:4
# 4.0    6338
# 3.0    2480
# 5.0    1084
# 2.0      23
# Name: educationalBackground, dtype: int64
# [first_proj_id]
# 缺失率：0%
# value_counts:3
# 32       9797
# 53        201
# 10601       1
# Name: first_proj_id, dtype: int64
# [gender]
# 缺失率：0%
# value_counts:2
# M    6535
# F    3464
# Name: gender, dtype: int64
# [graduateSchool]
# 缺失率：1%
# value_counts:479
# 武汉职业技术学院            324
# 湖北科技职业学院            119
# 武汉城市职业学院            115
# 华中师范大学                100
# 武汉工商学院                 90
# 汉口学院                     89
# 武汉交通职业学院             87
# 河南职业技术学院             75
# 长江工程职业技术学院         75
# 武汉生物工程学院             73
# 郑州财经学院                 72
# 武汉大学                     70
# 石家庄职业技术学院           69
# 湖北生态工程职业技术学院     69
# 漯河食品职业学院             69
# 长江职业学院                 69
# 武汉船舶职业技术学院         66
# 武汉商贸职业学院             62
# 国家开放大学                 62
# 山西应用科技学院             62
# 中原工学院                   60
# 湖北轻工职业技术学院         57
# 湖北商贸学院                 56
# 武汉理工大学                 56
# 北京航空航天大学             56
# 河南师范大学                 53
# 武汉软件工程职业学院         51
# 河南机电高等专科学校         50
# 武汉航海职业技术学院         50
# 河北工程技术学院             49
# 武汉工程职业技术学院         48
# 河间职教                     46
# 上海海事大学                 45
# 邢台职业技术学院             44
# 文华学院                     44
# 湖北第二师范学院             43
# 武汉商学院                   43
# 武汉科技职业学院             42
# 北京企业管理学院             42
# 晋中职业技术学院             42
# 济宁学院                     42
# 井冈山大学                   42
# 中南民族大学                 42
# 长江大学                     41
# 长江大学工程技术学院         41
# 黄冈职业技术学院             41
# 北京市工业技师学院           41
# 襄阳职业技术学院             41
# 湖北文理学院                 41
# 天津机电职业技术学院         41
# Name: graduateSchool, dtype: int64
# [major]
# 缺失率：11%
# value_counts:263
# 无                  497
# 市场营销            417
# 会计                359
# 电子商务            294
# 计算机              197
# 工商管理            182
# 行政管理            161
# 建筑工程技术        153
# 国际经济与贸易      127
# 机电一体化          127
# 物流管理            119
# 电子信息工程        119
# 计算机网络技术      114
# 商务英语            111
# 文科                110
# 计算机应用          110
# 工商企业管理        104
# 计算机应用技术      103
# 学前教育            100
# 工程造价            100
# 机械制造与自动化     96
# 人力资源管理         95
# 艺术设计             93
# 会计电算化           91
# 连锁经营管理         89
# 软件技术             85
# 航海技术             84
# 数控                 80
# 汉语言文学           79
# 金融                 74
# 软件工程             73
# 模具设计与制造       70
# 土木工程             70
# 食品营养与检测       69
# 数控技术             69
# 酒店管理             66
# 财务管理             65
# 电气自动化           63
# 社会工作             62
# 教育技术学           58
# 汽车检测与维修       55
# 应用电子技术         52
# 动漫设计             51
# 电线电缆制造技术     50
# 体育教育             48
# 汽修                 47
# 机械制造及自动化     46
# 旅游管理             45
# 汽车运用技术         45
# 园林                 44
# Name: major, dtype: int64
# [marriageState]
# 缺失率：0%
# value_counts:4
# 1    8833
# 4     932
# 3     172
# 2      62
# Name: marriageState, dtype: int64
# [nationalEdu]
# 缺失率：1%
# value_counts:2
# 1.0    7939
# 2.0    1986
# Name: nationalEdu, dtype: int64
# [oppor_source]
# 缺失率：0%
# value_counts:3
# MESSAGE_NEW_INSERT         5578
# ONLINE_CS_GREATBEAR        4418
# ONLINE_CS_SUNLANDS-ZLCX       3
# Name: oppor_source, dtype: int64
# [posLevel]
# 缺失率：0%
# value_counts:6
# 1     9817
# 2      122
# 3       42
# 0       11
# 4        4
# 17       3
# Name: posLevel, dtype: int64
# [promotion_type]
# 缺失率：0%
# value_counts:5
# APP      7451
# SEM      1650
# DSP       586
# OTHER     308
# None        4
# Name: promotion_type, dtype: int64
# [quantum_id]
# 缺失率：0%
# value_counts:12
# 2030016    2394
# 2030038    1862
# 2030006    1563
# 2030001    1050
# 2030007     895
# 2030034     728
# 2030004     487
# 2030088     469
# 2030091     259
# 2030009     251
# 2030203      37
# 2030110       4
# Name: quantum_id, dtype: int64
# [race]
# 缺失率：0%
# value_counts:10
# 汉        9473
# 满         299
# 土家        92
# 回          32
# 蒙古        22
# 维吾尔      21
# 侗          20
# 苗          18
# 白          18
# 彝           4
# Name: race, dtype: int64
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20375 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22238 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22303 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 23478 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 24413 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27721 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 28385 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 30333 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 32500 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21566 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 23572 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 33495 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 33945 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21476 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 20375 missing from current font.
#   font.load_char(ord(s), flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 22238 missing from current font.
#   font.load_char(ord(s), flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22303 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 23478 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 24413 missing from current font.
#   font.load_char(ord(s), flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 27721 missing from current font.
#   font.load_char(ord(s), flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 28385 missing from current font.
#   font.load_char(ord(s), flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 30333 missing from current font.
#   font.load_char(ord(s), flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 32500 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21566 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 23572 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 33495 missing from current font.
#   font.load_char(ord(s), flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 33945 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Program_Files\Adaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21476 missing from current font.
#   font.set_text(s, 0, flags=flags)
# [residenceType]
# 缺失率：1%
# value_counts:4
# 4.0    6423
# 3.0    1591
# 2.0     982
# 1.0     877
# Name: residenceType, dtype: int64
# [site_source]
# 缺失率：0%
# value_counts:73
# 腾讯广点通极速APP下载           1590
# 腾讯广点通广点通                1158
# 百度搜索搜索                    1056
# 今日头条极速APP下载              931
# 微信朋友圈移动平台               803
# 腾讯广点通搜索                   794
# 微信朋友圈微信                   493
# 360网盟网盟                      449
# 腾讯广点通网盟                   365
# 今日头条网盟                     281
# 微信朋友圈SEO                    254
# 搜狗搜索搜索                     249
# app下载无归属录入极速APP下载     222
# 神马搜索搜索                     200
# 腾讯广点通导航                   177
# 百度Feeds流搜索                  163
# 360搜索搜索                      138
# 百度品专搜索                      62
# 百度Feeds流网盟                   57
# 360网盟移动平台                   45
# 百度Feeds流导航                   39
# 今日头条APP下载                   38
# 快手极速APP下载                   38
# 主APP无归属录入未知               36
# UC头条导航                        32
# 360网盟导航                       30
# 腾讯广点通SEO                     22
# 腾讯广点通DSP                     21
# 腾讯广点通直播流量                21
# 腾讯广点通移动平台                20
# 微信朋友圈网盟                    20
# 今日头条导航                      17
# 微信公众号微信                    16
# 今日头条搜索                      16
# 微信朋友圈搜索                    10
# 360品专搜索                       10
# 今日头条SEO                       10
# app下载无归属录入APP下载          10
# 知乎SEO                            9
# 百度Feeds流SEO                     8
# 360移动推广极速APP下载             8
# 快手网盟                           7
# 微信公众号网盟                     7
# 金山WPS搜索                        5
# 百度搜索极速APP下载                4
# 华为信息流移动平台                 4
# 腾讯广点通微信                     4
# 今日头条软文广告                   4
# 微信朋友圈汇算                     4
# 华为移动平台                       4
# Name: site_source, dtype: int64
# [student_cellphone_midnum]
# 缺失率：45%
# value_counts:3920
# 9391.0    7
# 9941.0    7
# 9946.0    6
# 998.0     6
# 908.0     6
# 978.0     6
# 9960.0    5
# 5387.0    5
# 5396.0    5
# 2160.0    5
# 5433.0    5
# 6195.0    5
# 2196.0    5
# 9316.0    5
# 9900.0    5
# 5583.0    5
# 9967.0    5
# 171.0     5
# 962.0     5
# 9527.0    5
# 6543.0    5
# 9544.0    5
# 9710.0    5
# 9981.0    5
# 1722.0    4
# 6954.0    4
# 995.0     4
# 1003.0    4
# 9552.0    4
# 9307.0    4
# 248.0     4
# 6176.0    4
# 1035.0    4
# 6154.0    4
# 2182.0    4
# 211.0     4
# 6133.0    4
# 6131.0    4
# 9905.0    4
# 9907.0    4
# 188.0     4
# 186.0     4
# 9228.0    4
# 9920.0    4
# 6684.0    4
# 6939.0    4
# 6214.0    4
# 639.0     4
# 6326.0    4
# 1977.0    4
# Name: student_cellphone_midnum, dtype: int64
# [twice_consult]
# 缺失率：90%
# value_counts:1
# 1.0    983
# Name: twice_consult, dtype: int64
